# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (1.7.2)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: scipy>=1.8.0 in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (2.2.6)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (1.5.3)
# [notice] A new release of pip is available: 23.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install pandas matplotlib seaborn tensorflow
# Out:
# Requirement already satisfied: pandas in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (2.3.3)
# Requirement already satisfied: matplotlib in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (3.10.8)
# Requirement already satisfied: seaborn in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (0.13.2)
# Requirement already satisfied: tensorflow in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (2.20.0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\moham\appdata\roaming\python\python310\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2.2.6)
# Requirement already satisfied: pytz>=2020.1 in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: pyparsing>=3 in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: pillow>=8 in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (12.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\moham\appdata\roaming\python\python310\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (2.32.5)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: setuptools in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (65.5.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (1.76.0)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (2.3.1)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (3.15.1)
# Requirement already satisfied: keras>=3.10.0 in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (3.12.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\moham\appdata\roaming\python\python310\site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\moham\appdata\roaming\python\python310\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (2.0.1)
# Requirement already satisfied: tensorboard~=2.20.0 in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: protobuf>=5.28.0 in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (6.33.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.46.3)
# Requirement already satisfied: rich in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from keras>=3.10.0->tensorflow) (14.3.1)
# Requirement already satisfied: namex in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from keras>=3.10.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from keras>=3.10.0->tensorflow) (0.18.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2026.1.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.1.5)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.10.1)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from rich->keras>=3.10.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\moham\appdata\roaming\python\python310\site-packages (from rich->keras>=3.10.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('Customer_churn.csv')

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges Churn
# 0           Electronic check          29.85         29.85    No
# 1               Mailed check          56.95        1889.5    No
# 2               Mailed check          53.85        108.15   Yes
# 3  Bank transfer (automatic)          42.30       1840.75    No
# 4           Electronic check          70.70        151.65   Yes
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
#  16  PaperlessBilling  7043 non-null   object
#  17  PaymentMethod     7043 non-null   object
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7043 non-null   object
#  20  Churn             7043 non-null   object
# dtypes: float64(1), int64(2), object(18)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
df=df.drop('customerID', axis=1)

# %%
df.isnull().sum()
# Out:
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   object
#  1   SeniorCitizen     7043 non-null   int64
#  2   Partner           7043 non-null   object
#  3   Dependents        7043 non-null   object
#  4   tenure            7043 non-null   int64
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  Contract          7043 non-null   object
#  15  PaperlessBilling  7043 non-null   object
#  16  PaymentMethod     7043 non-null   object
#  17  MonthlyCharges    7043 non-null   float64
#  18  TotalCharges      7043 non-null   object
#  19  Churn             7043 non-null   object
# dtypes: float64(1), int64(2), object(17)
# memory usage: 1.1+ MB

# %%
df['TotalCharges']=pd.to_numeric(df['TotalCharges'], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   object
#  1   SeniorCitizen     7043 non-null   int64
#  2   Partner           7043 non-null   object
#  3   Dependents        7043 non-null   object
#  4   tenure            7043 non-null   int64
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  Contract          7043 non-null   object
#  15  PaperlessBilling  7043 non-null   object
#  16  PaymentMethod     7043 non-null   object
#  17  MonthlyCharges    7043 non-null   float64
#  18  TotalCharges      7032 non-null   float64
#  19  Churn             7043 non-null   object
# dtypes: float64(2), int64(2), object(16)
# memory usage: 1.1+ MB

# %%
for col in df.columns:
    print(f"Unique values for {col}:")
    print(df[col].unique())
# Out:
# Unique values for gender:
# ['Female' 'Male']
# Unique values for SeniorCitizen:
# [0 1]
# Unique values for Partner:
# ['Yes' 'No']
# Unique values for Dependents:
# ['No' 'Yes']
# Unique values for tenure:
# [ 1 34  2 45  8 22 10 28 62 13 16 58 49 25 69 52 71 21 12 30 47 72 17 27
#   5 46 11 70 63 43 15 60 18 66  9  3 31 50 64 56  7 42 35 48 29 65 38 68
#  32 55 37 36 41  6  4 33 67 23 57 61 14 20 53 40 59 24 44 19 54 51 26  0
#  39]
# Unique values for PhoneService:
# ['No' 'Yes']
# Unique values for MultipleLines:
# ['No phone service' 'No' 'Yes']
# Unique values for InternetService:
# ['DSL' 'Fiber optic' 'No']
# Unique values for OnlineSecurity:
# ['No' 'Yes' 'No internet service']
# Unique values for OnlineBackup:
# ['Yes' 'No' 'No internet service']
# Unique values for DeviceProtection:
# ['No' 'Yes' 'No internet service']
# Unique values for TechSupport:
# ['No' 'Yes' 'No internet service']
# Unique values for StreamingTV:
# ['No' 'Yes' 'No internet service']
# Unique values for StreamingMovies:
# ['No' 'Yes' 'No internet service']
# Unique values for Contract:
# ['Month-to-month' 'One year' 'Two year']
# Unique values for PaperlessBilling:
# ['Yes' 'No']
# Unique values for PaymentMethod:
# ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# Unique values for MonthlyCharges:
# [29.85 56.95 53.85 ... 63.1  44.2  78.7 ]
# Unique values for TotalCharges:
# [  29.85 1889.5   108.15 ...  346.45  306.6  6844.5 ]
# Unique values for Churn:
# ['No' 'Yes']

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.histplot(df['tenure'])
# Out:
# <Axes: xlabel='tenure', ylabel='Count'>

# %%
num_cols = df.select_dtypes(include=['int64', 'float64']).columns
num_cols


for col in num_cols:
    plt.figure(figsize=(5, 2))
    print(sns.boxplot(x=df[col]))
# Out:
# Axes(0.125,0.11;0.775x0.77)
# Axes(0.125,0.11;0.775x0.77)
# Axes(0.125,0.11;0.775x0.77)
# Axes(0.125,0.11;0.775x0.77)

# %%
for col in df.columns:
    plt.figure(figsize=(5, 2))
    print(sns.countplot(x=df[col], hue=df['Churn']))
# Out:
# Axes(0.125,0.11;0.775x0.77)
# Axes(0.125,0.11;0.775x0.77)
# Axes(0.125,0.11;0.775x0.77)
# Axes(0.125,0.11;0.775x0.77)
# Axes(0.125,0.11;0.775x0.77)
# Axes(0.125,0.11;0.775x0.77)
# Axes(0.125,0.11;0.775x0.77)
# Axes(0.125,0.11;0.775x0.77)
# Axes(0.125,0.11;0.775x0.77)
# Axes(0.125,0.11;0.775x0.77)
# Axes(0.125,0.11;0.775x0.77)
# Axes(0.125,0.11;0.775x0.77)
# Axes(0.125,0.11;0.775x0.77)
# Axes(0.125,0.11;0.775x0.77)
# Axes(0.125,0.11;0.775x0.77)
# Axes(0.125,0.11;0.775x0.77)
# Axes(0.125,0.11;0.775x0.77)
# Axes(0.125,0.11;0.775x0.77)
# Axes(0.125,0.11;0.775x0.77)
# Axes(0.125,0.11;0.775x0.77)

# %%
for col in num_cols:
    plt.figure(figsize=(5, 3))
    sns.histplot(data=df, x=col, hue='Churn', bins=30, kde=True)
    plt.title(f"{col} distribution by Churn")
    plt.show()

# %%
df['Churn'].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, StandardScaler

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   object
#  1   SeniorCitizen     7043 non-null   int64
#  2   Partner           7043 non-null   object
#  3   Dependents        7043 non-null   object
#  4   tenure            7043 non-null   int64
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  Contract          7043 non-null   object
#  15  PaperlessBilling  7043 non-null   object
#  16  PaymentMethod     7043 non-null   object
#  17  MonthlyCharges    7043 non-null   float64
#  18  TotalCharges      7032 non-null   float64
#  19  Churn             7043 non-null   object
# dtypes: float64(2), int64(2), object(16)
# memory usage: 1.1+ MB

# %%
for col in df.columns:
    print(f"Unique values for {col}:")
    print(df[col].unique())
# Out:
# Unique values for gender:
# ['Female' 'Male']
# Unique values for SeniorCitizen:
# [0 1]
# Unique values for Partner:
# ['Yes' 'No']
# Unique values for Dependents:
# ['No' 'Yes']
# Unique values for tenure:
# [ 1 34  2 45  8 22 10 28 62 13 16 58 49 25 69 52 71 21 12 30 47 72 17 27
#   5 46 11 70 63 43 15 60 18 66  9  3 31 50 64 56  7 42 35 48 29 65 38 68
#  32 55 37 36 41  6  4 33 67 23 57 61 14 20 53 40 59 24 44 19 54 51 26  0
#  39]
# Unique values for PhoneService:
# ['No' 'Yes']
# Unique values for MultipleLines:
# ['No phone service' 'No' 'Yes']
# Unique values for InternetService:
# ['DSL' 'Fiber optic' 'No']
# Unique values for OnlineSecurity:
# ['No' 'Yes' 'No internet service']
# Unique values for OnlineBackup:
# ['Yes' 'No' 'No internet service']
# Unique values for DeviceProtection:
# ['No' 'Yes' 'No internet service']
# Unique values for TechSupport:
# ['No' 'Yes' 'No internet service']
# Unique values for StreamingTV:
# ['No' 'Yes' 'No internet service']
# Unique values for StreamingMovies:
# ['No' 'Yes' 'No internet service']
# Unique values for Contract:
# ['Month-to-month' 'One year' 'Two year']
# Unique values for PaperlessBilling:
# ['Yes' 'No']
# Unique values for PaymentMethod:
# ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# Unique values for MonthlyCharges:
# [29.85 56.95 53.85 ... 63.1  44.2  78.7 ]
# Unique values for TotalCharges:
# [  29.85 1889.5   108.15 ...  346.45  306.6  6844.5 ]
# Unique values for Churn:
# ['No' 'Yes']

# %%
df.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# 1              Yes          No          No              No        One year
# 2               No          No          No              No  Month-to-month
# 3              Yes         Yes          No              No        One year
# 4               No          No          No              No  Month-to-month
#
#   PaperlessBilling              PaymentMethod  MonthlyCharges  TotalCharges  \
# 0              Yes           Electronic check           29.85         29.85
# 1               No               Mailed check           56.95       1889.50
# 2              Yes               Mailed check           53.85        108.15
# 3               No  Bank transfer (automatic)           42.30       1840.75
# 4              Yes           Electronic check           70.70        151.65
#
#   Churn
# 0    No
# 1    No
# 2   Yes
# 3    No
# 4   Yes

# %%
df['gender']=df['gender'].replace({'Male':0, 'Female':1})
df[['Partner', 'Dependents', 'PhoneService', 'PaperlessBilling']]=df[['Partner', 'Dependents', 'PhoneService', 'PaperlessBilling']].replace({'Yes':1, 'No':0})
# Out:
# C:\Users\moham\AppData\Local\Temp\ipykernel_21036\3526993553.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['gender']=df['gender'].replace({'Male':0, 'Female':1})
# C:\Users\moham\AppData\Local\Temp\ipykernel_21036\3526993553.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[['Partner', 'Dependents', 'PhoneService', 'PaperlessBilling']]=df[['Partner', 'Dependents', 'PhoneService', 'PaperlessBilling']].replace({'Yes':1, 'No':0})

# %%
df.head()
# Out:
#    gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0       1              0        1           0       1             0
# 1       0              0        0           0      34             1
# 2       0              0        0           0       2             1
# 3       0              0        0           0      45             0
# 4       1              0        0           0       2             1
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# 1              Yes          No          No              No        One year
# 2               No          No          No              No  Month-to-month
# 3              Yes         Yes          No              No        One year
# 4               No          No          No              No  Month-to-month
#
#    PaperlessBilling              PaymentMethod  MonthlyCharges  TotalCharges  \
# 0                 1           Electronic check           29.85         29.85
# 1                 0               Mailed check           56.95       1889.50
# 2                 1               Mailed check           53.85        108.15
# 3                 0  Bank transfer (automatic)           42.30       1840.75
# 4                 1           Electronic check           70.70        151.65
#
#   Churn
# 0    No
# 1    No
# 2   Yes
# 3    No
# 4   Yes

# %%
X=df.drop('Churn', axis=1)
y=df['Churn']

from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=45, stratify=y)

# %%
X_train
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 6453       0              1        1           0      47             1
# 1584       1              1        0           0      65             0
# 4239       0              0        1           1      56             0
# 3466       0              0        1           1      72             1
# 5861       0              0        0           0      35             1
# ...      ...            ...      ...         ...     ...           ...
# 3683       0              0        1           0      71             1
# 676        1              0        0           0      48             1
# 454        1              0        1           0      61             1
# 6558       0              0        0           0      16             1
# 3881       0              0        1           0      71             1
#
#          MultipleLines InternetService       OnlineSecurity  \
# 6453               Yes     Fiber optic                   No
# 1584  No phone service             DSL                   No
# 4239  No phone service             DSL                   No
# 3466               Yes              No  No internet service
# 5861                No              No  No internet service
# ...                ...             ...                  ...
# 3683                No             DSL                  Yes
# 676                Yes              No  No internet service
# 454                Yes              No  No internet service
# 6558                No              No  No internet service
# 3881               Yes             DSL                  Yes
#
#              OnlineBackup     DeviceProtection          TechSupport  \
# 6453                   No                  Yes                   No
# 1584                  Yes                  Yes                   No
# 4239                  Yes                  Yes                   No
# 3466  No internet service  No internet service  No internet service
# 5861  No internet service  No internet service  No internet service
# ...                   ...                  ...                  ...
# 3683                   No                   No                  Yes
# 676   No internet service  No internet service  No internet service
# 454   No internet service  No internet service  No internet service
# 6558  No internet service  No internet service  No internet service
# 3881                  Yes                   No                  Yes
#
#               StreamingTV      StreamingMovies        Contract  \
# 6453                  Yes                  Yes  Month-to-month
# 1584                  Yes                  Yes        Two year
# 4239                   No                   No        One year
# 3466  No internet service  No internet service        Two year
# 5861  No internet service  No internet service        Two year
# ...                   ...                  ...             ...
# 3683                   No                   No        Two year
# 676   No internet service  No internet service        One year
# 454   No internet service  No internet service        Two year
# 6558  No internet service  No internet service  Month-to-month
# 3881                   No                   No        Two year
#
#       PaperlessBilling              PaymentMethod  MonthlyCharges  \
# 6453                 1           Electronic check          100.05
# 1584                 1  Bank transfer (automatic)           53.50
# 4239                 1    Credit card (automatic)           36.10
# 3466                 1    Credit card (automatic)           25.10
# 5861                 0               Mailed check           19.25
# ...                ...                        ...             ...
# 3683                 0  Bank transfer (automatic)           54.50
# 676                  0  Bank transfer (automatic)           24.55
# 454                  0               Mailed check           24.40
# 6558                 0  Bank transfer (automatic)           20.25
# 3881                 0  Bank transfer (automatic)           65.15
#
#       TotalCharges
# 6453       4871.05
# 1584       3517.90
# 4239       1971.50
# 3466       1790.80
# 5861        677.90
# ...            ...
# 3683       3778.20
# 676        1203.95
# 454        1417.90
# 6558        327.45
# 3881       4681.75
#
# [5634 rows x 19 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   int64
#  1   SeniorCitizen     7043 non-null   int64
#  2   Partner           7043 non-null   int64
#  3   Dependents        7043 non-null   int64
#  4   tenure            7043 non-null   int64
#  5   PhoneService      7043 non-null   int64
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  Contract          7043 non-null   object
#  15  PaperlessBilling  7043 non-null   int64
#  16  PaymentMethod     7043 non-null   object
#  17  MonthlyCharges    7043 non-null   float64
#  18  TotalCharges      7032 non-null   float64
#  19  Churn             7043 non-null   object
# dtypes: float64(2), int64(7), object(11)
# memory usage: 1.1+ MB

# %%
ohe_cols = [
    'MultipleLines', 'InternetService', 'OnlineSecurity',
    'OnlineBackup', 'DeviceProtection', 'TechSupport',
    'StreamingTV', 'StreamingMovies', 'Contract'
]

# %%
ohe=OneHotEncoder(drop='first', sparse_output=False, handle_unknown='ignore')
X_train_ohe=ohe.fit_transform(X_train[ohe_cols])
X_test_ohe=ohe.transform(X_test[ohe_cols])

# %%
ohe_cols_new=ohe.get_feature_names_out(ohe_cols)

X_train_ohe = pd.DataFrame(
    X_train_ohe,
    columns=ohe_cols_new,
    index=X_train.index
)

X_test_ohe = pd.DataFrame(
    X_test_ohe,
    columns=ohe_cols_new,
    index=X_test.index
)

# %%
X_train = X_train.drop(columns=ohe_cols)
X_test  = X_test.drop(columns=ohe_cols)

# %%
X_train = pd.concat([X_train, X_train_ohe], axis=1)
X_test  = pd.concat([X_test, X_test_ohe], axis=1)

# %%
X_train.shape, X_test.shape
# Out:
# ((5634, 28), (1409, 28))

# %%
X_train_pm=ohe.fit_transform(X_train[['PaymentMethod']])

# %%
X_test_pm=ohe.transform(X_test[['PaymentMethod']])

# %%
pm_cols=ohe.get_feature_names_out(['PaymentMethod'])

# %%
X_train_pm = pd.DataFrame(X_train_pm, columns=pm_cols, index=X_train.index)
X_test_pm  = pd.DataFrame(X_test_pm, columns=pm_cols, index=X_test.index)

# %%
X_train = X_train.drop(columns=['PaymentMethod'])
X_test  = X_test.drop(columns=['PaymentMethod'])

# %%
X_train = pd.concat([X_train, X_train_pm], axis=1)
X_test  = pd.concat([X_test, X_test_pm], axis=1)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5634 entries, 6453 to 3881
# Data columns (total 30 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   gender                                 5634 non-null   int64
#  1   SeniorCitizen                          5634 non-null   int64
#  2   Partner                                5634 non-null   int64
#  3   Dependents                             5634 non-null   int64
#  4   tenure                                 5634 non-null   int64
#  5   PhoneService                           5634 non-null   int64
#  6   PaperlessBilling                       5634 non-null   int64
#  7   MonthlyCharges                         5634 non-null   float64
#  8   TotalCharges                           5623 non-null   float64
#  9   MultipleLines_No phone service         5634 non-null   float64
#  10  MultipleLines_Yes                      5634 non-null   float64
#  11  InternetService_Fiber optic            5634 non-null   float64
#  12  InternetService_No                     5634 non-null   float64
#  13  OnlineSecurity_No internet service     5634 non-null   float64
#  14  OnlineSecurity_Yes                     5634 non-null   float64
#  15  OnlineBackup_No internet service       5634 non-null   float64
#  16  OnlineBackup_Yes                       5634 non-null   float64
#  17  DeviceProtection_No internet service   5634 non-null   float64
#  18  DeviceProtection_Yes                   5634 non-null   float64
#  19  TechSupport_No internet service        5634 non-null   float64
#  20  TechSupport_Yes                        5634 non-null   float64
#  21  StreamingTV_No internet service        5634 non-null   float64
#  22  StreamingTV_Yes                        5634 non-null   float64
#  23  StreamingMovies_No internet service    5634 non-null   float64
#  24  StreamingMovies_Yes                    5634 non-null   float64
#  25  Contract_One year                      5634 non-null   float64
#  26  Contract_Two year                      5634 non-null   float64
#  27  PaymentMethod_Credit card (automatic)  5634 non-null   float64
#  28  PaymentMethod_Electronic check         5634 non-null   float64
#  29  PaymentMethod_Mailed check             5634 non-null   float64
# dtypes: float64(23), int64(7)
# memory usage: 1.3 MB

# %%
y_train.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 5634 entries, 6453 to 3881
# Series name: Churn
# Non-Null Count  Dtype
# --------------  -----
# 5634 non-null   object
# dtypes: object(1)
# memory usage: 88.0+ KB

# %%
y_train = y_train.map({'Yes': 1, 'No': 0})
y_test  = y_test.map({'Yes': 1, 'No': 0})

# %%
y_train.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 5634 entries, 6453 to 3881
# Series name: Churn
# Non-Null Count  Dtype
# --------------  -----
# 5634 non-null   int64
# dtypes: int64(1)
# memory usage: 88.0 KB

# %%
X_train.head()
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 6453       0              1        1           0      47             1
# 1584       1              1        0           0      65             0
# 4239       0              0        1           1      56             0
# 3466       0              0        1           1      72             1
# 5861       0              0        0           0      35             1
#
#       PaperlessBilling  MonthlyCharges  TotalCharges  \
# 6453                 1          100.05       4871.05
# 1584                 1           53.50       3517.90
# 4239                 1           36.10       1971.50
# 3466                 1           25.10       1790.80
# 5861                 0           19.25        677.90
#
#       MultipleLines_No phone service  ...  TechSupport_Yes  \
# 6453                             0.0  ...              0.0
# 1584                             1.0  ...              0.0
# 4239                             1.0  ...              0.0
# 3466                             0.0  ...              0.0
# 5861                             0.0  ...              0.0
#
#       StreamingTV_No internet service  StreamingTV_Yes  \
# 6453                              0.0              1.0
# 1584                              0.0              1.0
# 4239                              0.0              0.0
# 3466                              1.0              0.0
# 5861                              1.0              0.0
#
#       StreamingMovies_No internet service  StreamingMovies_Yes  \
# 6453                                  0.0                  1.0
# 1584                                  0.0                  1.0
# 4239                                  0.0                  0.0
# 3466                                  1.0                  0.0
# 5861                                  1.0                  0.0
#
#       Contract_One year  Contract_Two year  \
# 6453                0.0                0.0
# 1584                0.0                1.0
# 4239                1.0                0.0
# 3466                0.0                1.0
# 5861                0.0                1.0
#
#       PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 6453                                    0.0                             1.0
# 1584                                    0.0                             0.0
# 4239                                    1.0                             0.0
# 3466                                    1.0                             0.0
# 5861                                    0.0                             0.0
#
#       PaymentMethod_Mailed check
# 6453                         0.0
# 1584                         0.0
# 4239                         0.0
# 3466                         0.0
# 5861                         1.0
#
# [5 rows x 30 columns]

# %%
#Identified missing TotalCharges for customers with 0 tenure.
# imputed with 0 to represent new accounts before first billing

X_train['TotalCharges'] = X_train['TotalCharges'].fillna(0)
X_test['TotalCharges']  = X_test['TotalCharges'].fillna(0)

# %%
from sklearn.preprocessing import StandardScaler

scale_cols = ['tenure', 'MonthlyCharges', 'TotalCharges']

scaler = StandardScaler()

X_train[scale_cols] = scaler.fit_transform(X_train[scale_cols])
X_test[scale_cols]  = scaler.transform(X_test[scale_cols])

# %%
X_train[scale_cols].describe()
# Out:
#              tenure  MonthlyCharges  TotalCharges
# count  5.634000e+03    5.634000e+03  5.634000e+03
# mean   1.235946e-16   -1.349451e-16  2.774572e-17
# std    1.000089e+00    1.000089e+00  1.000089e+00
# min   -1.311997e+00   -1.548045e+00 -1.001976e+00
# 25%   -9.450820e-01   -9.642385e-01 -8.268460e-01
# 50%   -1.704832e-01    1.866947e-01 -3.924051e-01
# 75%    9.302624e-01    8.384732e-01  6.671389e-01
# max    1.623324e+00    1.804673e+00  2.834258e+00

# %%
y_train.value_counts(normalize=True)
# Out:
# Churn
# 0    0.734647
# 1    0.265353
# Name: proportion, dtype: float64

# %%
X_train.isnull().sum()
# Out:
# gender                                   0
# SeniorCitizen                            0
# Partner                                  0
# Dependents                               0
# tenure                                   0
# PhoneService                             0
# PaperlessBilling                         0
# MonthlyCharges                           0
# TotalCharges                             0
# MultipleLines_No phone service           0
# MultipleLines_Yes                        0
# InternetService_Fiber optic              0
# InternetService_No                       0
# OnlineSecurity_No internet service       0
# OnlineSecurity_Yes                       0
# OnlineBackup_No internet service         0
# OnlineBackup_Yes                         0
# DeviceProtection_No internet service     0
# DeviceProtection_Yes                     0
# TechSupport_No internet service          0
# TechSupport_Yes                          0
# StreamingTV_No internet service          0
# StreamingTV_Yes                          0
# StreamingMovies_No internet service      0
# StreamingMovies_Yes                      0
# Contract_One year                        0
# Contract_Two year                        0
# PaymentMethod_Credit card (automatic)    0
# PaymentMethod_Electronic check           0
# PaymentMethod_Mailed check               0
# dtype: int64

# %%
# !pip install imbalanced-learn
# Out:
# Collecting imbalanced-learn
#   Downloading imbalanced_learn-0.14.1-py3-none-any.whl (235 kB)
#      ---------------------------------------- 0.0/235.4 kB ? eta -:--:--
#      ------ -------------------------------- 41.0/235.4 kB 1.9 MB/s eta 0:00:01
#      ------------------------------- ------ 194.6/235.4 kB 2.4 MB/s eta 0:00:01
#      -------------------------------------- 235.4/235.4 kB 2.4 MB/s eta 0:00:00
# Collecting sklearn-compat<0.2,>=0.1.5
#   Downloading sklearn_compat-0.1.5-py3-none-any.whl (20 kB)
# Requirement already satisfied: scipy<2,>=1.11.4 in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from imbalanced-learn) (1.15.3)
# Requirement already satisfied: numpy<3,>=1.25.2 in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from imbalanced-learn) (2.2.6)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from imbalanced-learn) (3.6.0)
# Requirement already satisfied: scikit-learn<2,>=1.4.2 in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from imbalanced-learn) (1.7.2)
# Requirement already satisfied: joblib<2,>=1.2.0 in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from imbalanced-learn) (1.5.3)
# Installing collected packages: sklearn-compat, imbalanced-learn
# Successfully installed imbalanced-learn-0.14.1 sklearn-compat-0.1.5
# [notice] A new release of pip is available: 23.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#minority upsampling done here🙂

from sklearn.utils import resample
train_df = pd.concat([X_train, y_train], axis=1)

#seperate them
majority = train_df[train_df['Churn'] == 0]
minority = train_df[train_df['Churn'] == 1]

# %%
from sklearn.utils import resample

minority_upsampled = resample(
    minority,
    replace=True,
    n_samples=len(majority),
    random_state=42
)

# %%
train_upsampled = pd.concat([majority, minority_upsampled])
train_upsampled = train_upsampled.sample(frac=1, random_state=42)


X_train_up = train_upsampled.drop('Churn', axis=1)
y_train_up = train_upsampled['Churn']

# %%
print(X_train_up.columns)
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'PaperlessBilling', 'MonthlyCharges', 'TotalCharges',
#        'MultipleLines_No phone service', 'MultipleLines_Yes',
#        'InternetService_Fiber optic', 'InternetService_No',
#        'OnlineSecurity_No internet service', 'OnlineSecurity_Yes',
#        'OnlineBackup_No internet service', 'OnlineBackup_Yes',
#        'DeviceProtection_No internet service', 'DeviceProtection_Yes',
#        'TechSupport_No internet service', 'TechSupport_Yes',
#        'StreamingTV_No internet service', 'StreamingTV_Yes',
#        'StreamingMovies_No internet service', 'StreamingMovies_Yes',
#        'Contract_One year', 'Contract_Two year',
#        'PaymentMethod_Credit card (automatic)',
#        'PaymentMethod_Electronic check', 'PaymentMethod_Mailed check'],
#       dtype='object')

# %%
#logistic regression without smote

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score

lr = LogisticRegression(max_iter=1000)
lr.fit(X_train_up, y_train_up)

y_pred = lr.predict(X_test)
y_prob = lr.predict_proba(X_test)[:, 1]

# %%
# tuning the threshold to find more churners.

thresholds=np.arange(0.25, 0.6, 0.05)
for t in thresholds:
    y_pred_thr= (y_prob>t).astype(int)
    print(f"threshold: {t}")
    print(classification_report(y_test, y_pred_thr))
# Out:
# threshold: 0.25
#               precision    recall  f1-score   support
#
#            0       0.95      0.49      0.64      1035
#            1       0.40      0.93      0.55       374
#
#     accuracy                           0.60      1409
#    macro avg       0.67      0.71      0.60      1409
# weighted avg       0.80      0.60      0.62      1409
#
# threshold: 0.3
#               precision    recall  f1-score   support
#
#            0       0.95      0.54      0.69      1035
#            1       0.42      0.92      0.58       374
#
#     accuracy                           0.64      1409
#    macro avg       0.68      0.73      0.63      1409
# weighted avg       0.81      0.64      0.66      1409
#
# threshold: 0.35
#               precision    recall  f1-score   support
#
#            0       0.94      0.58      0.72      1035
#            1       0.44      0.90      0.59       374
#
#     accuracy                           0.66      1409
#    macro avg       0.69      0.74      0.65      1409
# weighted avg       0.81      0.66      0.68      1409
#
# threshold: 0.39999999999999997
#               precision    recall  f1-score   support
#
#            0       0.94      0.62      0.75      1035
#            1       0.46      0.89      0.60       374
#
#     accuracy                           0.69      1409
#    macro avg       0.70      0.75      0.68      1409
# weighted avg       0.81      0.69      0.71      1409
#
# threshold: 0.44999999999999996
#               precision    recall  f1-score   support
#
#            0       0.93      0.67      0.78      1035
#            1       0.48      0.85      0.62       374
#
#     accuracy                           0.72      1409
#    macro avg       0.71      0.76      0.70      1409
# weighted avg       0.81      0.72      0.74      1409
#
# threshold: 0.49999999999999994
#               precision    recall  f1-score   support
#
#            0       0.92      0.71      0.80      1035
#            1       0.51      0.82      0.63       374
#
#     accuracy                           0.74      1409
#    macro avg       0.71      0.77      0.71      1409
# weighted avg       0.81      0.74      0.76      1409
#
# threshold: 0.5499999999999999
#               precision    recall  f1-score   support
#
#            0       0.90      0.75      0.82      1035
#            1       0.53      0.78      0.63       374
#
#     accuracy                           0.76      1409
#    macro avg       0.71      0.76      0.72      1409
# weighted avg       0.80      0.76      0.77      1409

# %%
y_prob = lr.predict_proba(X_test)[:, 1]
y_pred_final = (y_prob > 0.40).astype(int)

# %%
print(confusion_matrix(y_test, y_pred_final))
print(classification_report(y_test, y_pred_final))
print("ROC-AUC:", roc_auc_score(y_test, y_prob))
# Out:
# [[644 391]
#  [ 43 331]]
#               precision    recall  f1-score   support
#
#            0       0.94      0.62      0.75      1035
#            1       0.46      0.89      0.60       374
#
#     accuracy                           0.69      1409
#    macro avg       0.70      0.75      0.68      1409
# weighted avg       0.81      0.69      0.71      1409
#
# ROC-AUC: 0.8354801209021159

# %%
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier(class_weight='balanced')
rfc.fit(X_train_up, y_train_up)

y_pred1=rfc.predict(X_test)
y_prob1 = rfc.predict_proba(X_test)[:, 1]
y_prob2= y_prob

# %%
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
print("ROC-AUC:", roc_auc_score(y_test, y_prob1))
# Out:
# [[737 298]
#  [ 67 307]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.71      0.80      1035
#            1       0.51      0.82      0.63       374
#
#     accuracy                           0.74      1409
#    macro avg       0.71      0.77      0.71      1409
# weighted avg       0.81      0.74      0.76      1409
#
# ROC-AUC: 0.817915730191945

# %%
from sklearn.model_selection import GridSearchCV

# Define the parameters to test
param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [10, 20, None],
    'min_samples_split': [2, 5],
    'class_weight': ['balanced']
}

# Initialize the grid search
grid_search = GridSearchCV(estimator=RandomForestClassifier(random_state=45), 
                           param_grid=param_grid, 
                           cv=3, scoring='roc_auc', n_jobs=-1)

# Fit the grid search
grid_search.fit(X_train_up, y_train_up)

# See the best parameters
print("Best Parameters:", grid_search.best_params_)
best_rfc = grid_search.best_estimator_
# Out:
# Best Parameters: {'class_weight': 'balanced', 'max_depth': None, 'min_samples_split': 2, 'n_estimators': 200}

# %%
import joblib

#the best parmeter found
best_rfc = RandomForestClassifier(
    n_estimators=200, 
    min_samples_split=2, 
    max_depth=None, 
    class_weight='balanced', 
    random_state=45
)

best_rfc.fit(X_train_up, y_train_up)


from sklearn.preprocessing import OneHotEncoder

# 1. Prepare the raw categorical data for fitting
# We use the original dataframe but filter for the columns we need
ohe_cols = ['MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 
            'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract']

# 2. Re-fit General Encoder
ohe_gen = OneHotEncoder(drop='first', sparse_output=False, handle_unknown='ignore')
ohe_gen.fit(df[ohe_cols]) 

# 3. Re-fit Payment Encoder
ohe_pay = OneHotEncoder(drop='first', sparse_output=False, handle_unknown='ignore')
ohe_pay.fit(df[['PaymentMethod']])

# 4. SAVE EVERYTHING
joblib.dump(best_rfc, 'final_churn_model.pkl')
joblib.dump(scaler, 'scaler.pkl')
joblib.dump(ohe_gen, 'ohe_general.pkl')
joblib.dump(ohe_pay, 'ohe_payment.pkl')

print("✅ Success! All 4 files saved correctly.")


print("Success: Best model, Scaler, and Encoder saved separately!")
# Out:
# ✅ Success! All 4 files saved correctly.
# Success: Best model, Scaler, and Encoder saved separately!

# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (2.20.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (2.0.1)
# Requirement already satisfied: packaging in c:\users\moham\appdata\roaming\python\python310\site-packages (from tensorflow) (26.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: protobuf>=5.28.0 in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (6.33.4)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (3.15.1)
# Requirement already satisfied: setuptools in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (65.5.0)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\moham\appdata\roaming\python\python310\site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: tensorboard~=2.20.0 in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (2.3.1)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (2.2.6)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (2.32.5)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: keras>=3.10.0 in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (3.12.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\moham\appdata\roaming\python\python310\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (1.76.0)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.46.3)
# Requirement already satisfied: optree in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from keras>=3.10.0->tensorflow) (0.18.0)
# Requirement already satisfied: namex in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from keras>=3.10.0->tensorflow) (0.1.0)
# Requirement already satisfied: rich in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from keras>=3.10.0->tensorflow) (14.3.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.6.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2026.1.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.1.5)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.10.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: pillow in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (12.1.0)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from rich->keras>=3.10.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\moham\appdata\roaming\python\python310\site-packages (from rich->keras>=3.10.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\moham\appdata\local\programs\python\python310\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from tensorflow.python import pywrap_tensorflow

# %%
import tensorflow as tf

# %%
from tensorflow import keras

# %%
model= keras.Sequential([
    keras.layers.Dense(32, input_shape=(X_train.shape[1],), activation='relu'),
    keras.layers.Dropout(0.3),
    keras.layers.Dense(16, activation='relu'),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(1, activation='sigmoid')
])
# Out:
# c:\Users\moham\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\core\dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['Accuracy', 'Recall', 'Precision', 'AUC'])

# %%
model.fit(X_train, y_train, epochs=30, batch_size=32, verbose=1, validation_split=0.2)
# Out:
# Epoch 1/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - AUC: 0.7242 - Accuracy: 0.7479 - Precision: 0.5562 - Recall: 0.2244 - loss: 0.5182 - val_AUC: 0.8102 - val_Accuracy: 0.7906 - val_Precision: 0.6605 - val_Recall: 0.4656 - val_loss: 0.4605
# Epoch 2/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8030 - Accuracy: 0.7761 - Precision: 0.6089 - Recall: 0.4252 - loss: 0.4613 - val_AUC: 0.8211 - val_Accuracy: 0.7924 - val_Precision: 0.6310 - val_Recall: 0.5607 - val_loss: 0.4487
# Epoch 3/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8265 - Accuracy: 0.7917 - Precision: 0.6303 - Recall: 0.5101 - loss: 0.4377 - val_AUC: 0.8250 - val_Accuracy: 0.7941 - val_Precision: 0.6377 - val_Recall: 0.5541 - val_loss: 0.4440
# Epoch 4/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8275 - Accuracy: 0.7921 - Precision: 0.6359 - Recall: 0.4975 - loss: 0.4368 - val_AUC: 0.8270 - val_Accuracy: 0.7977 - val_Precision: 0.6332 - val_Recall: 0.6000 - val_loss: 0.4426
# Epoch 5/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8381 - Accuracy: 0.8061 - Precision: 0.6632 - Recall: 0.5395 - loss: 0.4251 - val_AUC: 0.8264 - val_Accuracy: 0.7977 - val_Precision: 0.6370 - val_Recall: 0.5869 - val_loss: 0.4426
# Epoch 6/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - AUC: 0.8354 - Accuracy: 0.8039 - Precision: 0.6515 - Recall: 0.5529 - loss: 0.4290 - val_AUC: 0.8264 - val_Accuracy: 0.7986 - val_Precision: 0.6403 - val_Recall: 0.5836 - val_loss: 0.4418
# Epoch 7/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8373 - Accuracy: 0.8025 - Precision: 0.6572 - Recall: 0.5269 - loss: 0.4265 - val_AUC: 0.8280 - val_Accuracy: 0.7977 - val_Precision: 0.6271 - val_Recall: 0.6230 - val_loss: 0.4425
# Epoch 8/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8404 - Accuracy: 0.7999 - Precision: 0.6449 - Recall: 0.5387 - loss: 0.4238 - val_AUC: 0.8287 - val_Accuracy: 0.7968 - val_Precision: 0.6275 - val_Recall: 0.6131 - val_loss: 0.4423
# Epoch 9/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8449 - Accuracy: 0.8001 - Precision: 0.6482 - Recall: 0.5311 - loss: 0.4163 - val_AUC: 0.8283 - val_Accuracy: 0.7968 - val_Precision: 0.6338 - val_Recall: 0.5902 - val_loss: 0.4410
# Epoch 10/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8451 - Accuracy: 0.8034 - Precision: 0.6580 - Recall: 0.5319 - loss: 0.4184 - val_AUC: 0.8282 - val_Accuracy: 0.7924 - val_Precision: 0.6237 - val_Recall: 0.5869 - val_loss: 0.4420
# Epoch 11/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8439 - Accuracy: 0.8023 - Precision: 0.6533 - Recall: 0.5353 - loss: 0.4194 - val_AUC: 0.8276 - val_Accuracy: 0.7870 - val_Precision: 0.6157 - val_Recall: 0.5672 - val_loss: 0.4421
# Epoch 12/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8474 - Accuracy: 0.8101 - Precision: 0.6729 - Recall: 0.5462 - loss: 0.4153 - val_AUC: 0.8281 - val_Accuracy: 0.7879 - val_Precision: 0.6279 - val_Recall: 0.5311 - val_loss: 0.4408
# Epoch 13/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8511 - Accuracy: 0.8087 - Precision: 0.6712 - Recall: 0.5403 - loss: 0.4110 - val_AUC: 0.8278 - val_Accuracy: 0.7879 - val_Precision: 0.6260 - val_Recall: 0.5377 - val_loss: 0.4414
# Epoch 14/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8515 - Accuracy: 0.8067 - Precision: 0.6724 - Recall: 0.5227 - loss: 0.4096 - val_AUC: 0.8295 - val_Accuracy: 0.7897 - val_Precision: 0.6250 - val_Recall: 0.5574 - val_loss: 0.4409
# Epoch 15/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8505 - Accuracy: 0.8043 - Precision: 0.6578 - Recall: 0.5395 - loss: 0.4113 - val_AUC: 0.8296 - val_Accuracy: 0.7906 - val_Precision: 0.6219 - val_Recall: 0.5770 - val_loss: 0.4416
# Epoch 16/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8504 - Accuracy: 0.8008 - Precision: 0.6466 - Recall: 0.5412 - loss: 0.4124 - val_AUC: 0.8281 - val_Accuracy: 0.7879 - val_Precision: 0.6352 - val_Recall: 0.5082 - val_loss: 0.4419
# Epoch 17/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8547 - Accuracy: 0.8087 - Precision: 0.6802 - Recall: 0.5202 - loss: 0.4068 - val_AUC: 0.8289 - val_Accuracy: 0.7862 - val_Precision: 0.6203 - val_Recall: 0.5410 - val_loss: 0.4410
# Epoch 18/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8526 - Accuracy: 0.8076 - Precision: 0.6746 - Recall: 0.5244 - loss: 0.4083 - val_AUC: 0.8299 - val_Accuracy: 0.7862 - val_Precision: 0.6185 - val_Recall: 0.5475 - val_loss: 0.4406
# Epoch 19/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8546 - Accuracy: 0.8105 - Precision: 0.6822 - Recall: 0.5286 - loss: 0.4076 - val_AUC: 0.8301 - val_Accuracy: 0.7879 - val_Precision: 0.6289 - val_Recall: 0.5279 - val_loss: 0.4400
# Epoch 20/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8552 - Accuracy: 0.8112 - Precision: 0.6813 - Recall: 0.5353 - loss: 0.4047 - val_AUC: 0.8289 - val_Accuracy: 0.7879 - val_Precision: 0.6387 - val_Recall: 0.4984 - val_loss: 0.4420
# Epoch 21/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8572 - Accuracy: 0.8101 - Precision: 0.6889 - Recall: 0.5118 - loss: 0.4034 - val_AUC: 0.8300 - val_Accuracy: 0.7862 - val_Precision: 0.6212 - val_Recall: 0.5377 - val_loss: 0.4407
# Epoch 22/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8526 - Accuracy: 0.8081 - Precision: 0.6764 - Recall: 0.5235 - loss: 0.4096 - val_AUC: 0.8303 - val_Accuracy: 0.7897 - val_Precision: 0.6405 - val_Recall: 0.5082 - val_loss: 0.4394
# Epoch 23/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8578 - Accuracy: 0.8090 - Precision: 0.6822 - Recall: 0.5176 - loss: 0.4029 - val_AUC: 0.8297 - val_Accuracy: 0.7870 - val_Precision: 0.6471 - val_Recall: 0.4689 - val_loss: 0.4397
# Epoch 24/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8566 - Accuracy: 0.8079 - Precision: 0.6871 - Recall: 0.5000 - loss: 0.4054 - val_AUC: 0.8307 - val_Accuracy: 0.7879 - val_Precision: 0.6299 - val_Recall: 0.5246 - val_loss: 0.4403
# Epoch 25/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8594 - Accuracy: 0.8092 - Precision: 0.6778 - Recall: 0.5286 - loss: 0.4005 - val_AUC: 0.8300 - val_Accuracy: 0.7897 - val_Precision: 0.6298 - val_Recall: 0.5410 - val_loss: 0.4427
# Epoch 26/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - AUC: 0.8637 - Accuracy: 0.8145 - Precision: 0.6879 - Recall: 0.5445 - loss: 0.3967 - val_AUC: 0.8291 - val_Accuracy: 0.7924 - val_Precision: 0.6254 - val_Recall: 0.5803 - val_loss: 0.4445
# Epoch 27/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - AUC: 0.8570 - Accuracy: 0.8105 - Precision: 0.6739 - Recall: 0.5471 - loss: 0.4042 - val_AUC: 0.8295 - val_Accuracy: 0.7870 - val_Precision: 0.6349 - val_Recall: 0.5016 - val_loss: 0.4402
# Epoch 28/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8603 - Accuracy: 0.8114 - Precision: 0.6848 - Recall: 0.5294 - loss: 0.4004 - val_AUC: 0.8292 - val_Accuracy: 0.7862 - val_Precision: 0.6212 - val_Recall: 0.5377 - val_loss: 0.4421
# Epoch 29/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8598 - Accuracy: 0.8145 - Precision: 0.6924 - Recall: 0.5353 - loss: 0.4019 - val_AUC: 0.8294 - val_Accuracy: 0.7853 - val_Precision: 0.6154 - val_Recall: 0.5508 - val_loss: 0.4425
# Epoch 30/30
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8548 - Accuracy: 0.8116 - Precision: 0.6793 - Recall: 0.5429 - loss: 0.4065 - val_AUC: 0.8293 - val_Accuracy: 0.7870 - val_Precision: 0.6327 - val_Recall: 0.5082 - val_loss: 0.4402

# %%
y_prob_ann = model.predict(X_test).ravel()
# Out:
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
for t in [0.25, 0.3, 0.35, 0.4, 0.45, 0.5]:
    y_pred = (y_prob_ann > t).astype(int)
    print("Threshold:", t)
    print(classification_report(y_test, y_pred))
# Out:
# Threshold: 0.25
#               precision    recall  f1-score   support
#
#            0       0.92      0.69      0.79      1035
#            1       0.49      0.83      0.62       374
#
#     accuracy                           0.73      1409
#    macro avg       0.71      0.76      0.70      1409
# weighted avg       0.81      0.73      0.74      1409
#
# Threshold: 0.3
#               precision    recall  f1-score   support
#
#            0       0.90      0.74      0.81      1035
#            1       0.52      0.76      0.62       374
#
#     accuracy                           0.75      1409
#    macro avg       0.71      0.75      0.71      1409
# weighted avg       0.80      0.75      0.76      1409
#
# Threshold: 0.35
#               precision    recall  f1-score   support
#
#            0       0.88      0.80      0.84      1035
#            1       0.56      0.69      0.62       374
#
#     accuracy                           0.77      1409
#    macro avg       0.72      0.75      0.73      1409
# weighted avg       0.79      0.77      0.78      1409
#
# Threshold: 0.4
#               precision    recall  f1-score   support
#
#            0       0.86      0.85      0.86      1035
#            1       0.60      0.62      0.61       374
#
#     accuracy                           0.79      1409
#    macro avg       0.73      0.73      0.73      1409
# weighted avg       0.79      0.79      0.79      1409
#
# Threshold: 0.45
#               precision    recall  f1-score   support
#
#            0       0.85      0.87      0.86      1035
#            1       0.62      0.56      0.59       374
#
#     accuracy                           0.79      1409
#    macro avg       0.73      0.72      0.73      1409
# weighted avg       0.79      0.79      0.79      1409
#
# Threshold: 0.5
#               precision    recall  f1-score   support
#
#            0       0.84      0.90      0.87      1035
#            1       0.64      0.52      0.57       374
#
#     accuracy                           0.80      1409
#    macro avg       0.74      0.71      0.72      1409
# weighted avg       0.79      0.80      0.79      1409

# %% [markdown]
# #key insights derived
#
# Customers on Month-to-Month contracts are the primary churn drivers.
# Moving these customers to 1-year contracts could reduce churn significantly.
